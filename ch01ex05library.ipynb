# %%
import pandas as pd

df = pd.read_csv(
    "C:/Users/Donga/Downloads/seoul_library_202511.csv",
    encoding="utf-8-sig"
)
# Out:
# C:\Users\Donga\AppData\Local\Temp\ipykernel_31728\3838135768.py:3: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df.columns
# Out:
# Index(['번호', '도서명', '저자', '출판사', '발행년도', 'ISBN', '세트 ISBN', '부가기호', '권',
#        '주제분류번호', '도서권수', '대출건수', '등록일자', 'Unnamed: 13'],
#       dtype='object')

# %%
loan_counts = df['도서명'].value_counts()

# %%
top10_books = loan_counts.head(10)
top10_books
# Out:
# 도서명
# 승정원일기                       268
# 일성록                         175
# (影印標點) 韓國文集叢刊 續             118
# 애거서 크리스티 전집                  80
# 三國志                          79
# (影印標點)韓國文集叢刊                 76
# 세상에 대하여 우리가 더 잘 알아야 할 교양     76
# 황금가지 애거서 크리스티 전집             72
# 한국 고전소설사 큰 사전                72
# 묵향                           70
# Name: count, dtype: int64

# %%
top10_df = top10_books.reset_index()
top10_df.columns = ['도서명', '대출건수']
top10_df
# Out:
#                         도서명  대출건수
# 0                     승정원일기   268
# 1                       일성록   175
# 2           (影印標點) 韓國文集叢刊 續   118
# 3               애거서 크리스티 전집    80
# 4                       三國志    79
# 5              (影印標點)韓國文集叢刊    76
# 6  세상에 대하여 우리가 더 잘 알아야 할 교양    76
# 7          황금가지 애거서 크리스티 전집    72
# 8             한국 고전소설사 큰 사전    72
# 9                        묵향    70

# %%
top10_df.to_csv(
    "C:/workspace/part2/book1/ch01/top10_most_borrowed_books.csv",
    index=False,
    encoding="utf-8-sig"
)
