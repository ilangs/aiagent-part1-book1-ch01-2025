# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
import pandas as pd

# %%
print("np.__version__:", np.__version__)
print("pd.__version__:", pd.__version__)
print("Matplotlib OK")
# Out:
# np.__version__: 2.3.5
# pd.__version__: 2.3.3
# Matplotlib OK

# %%
test_list = [7,8,4,5,1,9,2,6,3]
df = pd.array(test_list)
print(df)
# Out:
# <IntegerArray>
# [7, 8, 4, 5, 1, 9, 2, 6, 3]
# Length: 9, dtype: Int64

# %%
print(df.mean()) # 넘파이 array의 평균
print(df.max()) # 넘파이 array의 최대값
# Out:
# 5.0
# 9
